# %%
from pogo import Pogo

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import  datasets, metrics
from sklearn.preprocessing import MinMaxScaler
from urllib.request import urlopen
from urllib.parse import urlparse
import os.path

# %%
pogo = Pogo()

# %%
#data from scikitlearn tutorial on clustering 

np.random.seed(0)

# ============
# Generate datasets. We choose the size big enough to see the scalability
# of the algorithms, but not too big to avoid too long running times
# ============
n_samples = 500
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=0.5, noise=0.05)
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=0.05)
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
no_structure = np.random.rand(n_samples, 2), None

# Anisotropicly distributed data
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)

# blobs with varied variances
varied = datasets.make_blobs(
    n_samples=n_samples, cluster_std=[1.0, 2.5, 0.5], random_state=random_state
)

# %%
X=varied[0]
y=varied[1]

size=8
plt.figure(figsize=(size,size))
plt.scatter(X[:, 0], X[:, 1],
            s=25, 
            c=y,
            marker="o",
            cmap='tab10',
            norm=None,
            alpha=.7,
            edgecolor="k")

# %%
pogo = Pogo()
pogo.fit(X)
pogo.plot()

# %%
pogo.initial_idx_
# Out:
# 12260

# %%
pogo.idx_
# Out:
# 11921

# %%
pogo.candidates_[:20]
# Out:
# [12260,
#  18297,
#  4283,
#  3849,
#  5883,
#  15860,
#  2662,
#  5369,
#  8546,
#  6926,
#  6221,
#  2443,
#  2544,
#  3485,
#  4560,
#  10186,
#  2213,
#  9244,
#  11139,
#  9570]

# %%
plt.plot(pogo.gap_vector_)

# %%
plt.plot(pogo.gap_vector_[:pogo.candidates_[0]])

# %%
silhouette_indices, silhouette_array = pogo.plot_silhouette()
# Out:
# Maximum Silhouette: 11921

# %%
score_indices, score_array = pogo.plot_silhouette_score()
# Out:
# Maximum Silhouette Score: 4283

# %%
rand_indices, rand_array = pogo.plot_rand_score(y)
# Out:
# Maximum Rand Score: 11921

# %%
X=noisy_circles[0]
y=noisy_circles[1]

size=8
plt.figure(figsize=(size,size))
plt.scatter(X[:, 0], X[:, 1],
            s=25, 
            #c=y,
            marker="o",
            cmap='tab10',
            norm=None,
            alpha=.7,
            edgecolor="k")

# %%
pogo = Pogo()
pogo.fit(X)
pogo.plot()

# %%
pogo.initial_idx_
# Out:
# 2389

# %%
pogo.idx_
# Out:
# 2320

# %%
pogo.candidates_[:20]
# Out:
# [2389,
#  2320,
#  2271,
#  2251,
#  2246,
#  2816,
#  2818,
#  2817,
#  3084,
#  3083,
#  3082,
#  2819,
#  2820,
#  3085,
#  3081,
#  2821,
#  2822,
#  2823,
#  2824,
#  2825]

# %%
plt.plot(pogo.gap_vector_)

# %%
plt.plot(pogo.gap_vector_[:pogo.candidates_[0]])

# %%
silhouette_indices, silhouette_array = pogo.plot_silhouette()
# Out:
# Maximum Silhouette: 2320

# %%
score_indices, score_array = pogo.plot_silhouette_score()
# Out:
# Maximum Silhouette Score: 2320

# %%
rand_indices, rand_array = pogo.plot_rand_score(y)
# Out:
# Maximum Rand Score: 2320

# %%
X=noisy_moons[0]
y=noisy_moons[1]

size=8
plt.figure(figsize=(size,size))
plt.scatter(X[:, 0], X[:, 1],
            s=25, 
            c=y,
            marker="o",
            cmap='tab10',
            norm=None,
            alpha=.7,
            edgecolor="k")

# %%
pogo = Pogo()
pogo.fit(X)
pogo.plot()

# %%
pogo.initial_idx_
# Out:
# 3659

# %%
pogo.idx_
# Out:
# 2107

# %%
pogo.candidates_[:10]
# Out:
# [3659, 2621, 2107, 2514, 12108, 4123, 4230, 4229, 4031, 4228]

# %%
plt.plot(pogo.gap_vector_)

# %%
plt.plot(pogo.gap_vector_[:pogo.candidates_[0]])

# %%
silhouette_indices, silhouette_array = pogo.plot_silhouette()
# Out:
# Maximum Silhouette: 2107

# %%
score_indices, score_array = pogo.plot_silhouette_score()
# Out:
# Maximum Silhouette Score: 2621

# %%
rand_indices, rand_array = pogo.plot_rand_score(y)
# Out:
# Maximum Rand Score: 2621

# %%
X=blobs[0]
y=blobs[1]

size=8
plt.figure(figsize=(size,size))
plt.scatter(X[:, 0], X[:, 1],
            s=25, 
            c=y,
            marker="o",
            cmap='tab10',
            norm=None,
            alpha=.7,
            edgecolor="k")

# %%
pogo = Pogo()
pogo.fit(X)
pogo.plot()

# %%
pogo.initial_idx_
# Out:
# 22008

# %%
pogo.idx_
# Out:
# 10585

# %%
pogo.candidates_[:20]
# Out:
# [22008,
#  40162,
#  16771,
#  12286,
#  5322,
#  8881,
#  6624,
#  10585,
#  4257,
#  7996,
#  3177,
#  2924,
#  2656,
#  5107,
#  4003,
#  3739,
#  2105,
#  2470,
#  2355,
#  2014]

# %%
plt.plot(pogo.gap_vector_)

# %%
plt.plot(pogo.gap_vector_[:pogo.candidates_[0]])

# %%
silhouette_indices, silhouette_array = pogo.plot_silhouette()
# Out:
# Maximum Silhouette: 10585

# %%
score_indices, score_array = pogo.plot_silhouette_score()
# Out:
# Maximum Silhouette Score: 16771

# %%
rand_indices, rand_array = pogo.plot_rand_score(y)
# Out:
# Maximum Rand Score: 16771

# %%
X=no_structure[0]
y=no_structure[1]

size=8
plt.figure(figsize=(size,size))
plt.scatter(X[:, 0], X[:, 1],
            s=25, 
            c=y,
            marker="o",
            cmap='tab10',
            norm=None,
            alpha=.7,
            edgecolor="k")

# %%
pogo = Pogo()
pogo.fit(X)
pogo.plot()

# %%
pogo.initial_idx_
# Out:
# 2091

# %%
pogo.idx_
# Out:
# 2091

# %%
pogo.candidates_[:20]
# Out:
# [2091,
#  2411,
#  2523,
#  3329,
#  2771,
#  2781,
#  2780,
#  2779,
#  2778,
#  2777,
#  2776,
#  2775,
#  2774,
#  2773,
#  2772,
#  2770,
#  2783,
#  2769,
#  2768,
#  2767]

# %%
plt.plot(pogo.gap_vector_)

# %%
plt.plot(pogo.gap_vector_[:pogo.candidates_[0]])

# %%
silhouette_indices, silhouette_array = pogo.plot_silhouette()

# %%
score_indices, score_array = pogo.plot_silhouette_score()

# %%
X=aniso[0]
y=aniso[1]

size=8
plt.figure(figsize=(size,size))
plt.scatter(X[:, 0], X[:, 1],
            s=25, 
            c=y,
            marker="o",
            cmap='tab10',
            norm=None,
            alpha=.7,
            edgecolor="k")

# %%
pogo = Pogo()
pogo.fit(X)
pogo.plot()

# %%
pogo.initial_idx_
# Out:
# 4803

# %%
pogo.idx_
# Out:
# 4003

# %%
pogo.candidates_[:20]
# Out:
# [4803,
#  3035,
#  8321,
#  7101,
#  2643,
#  4003,
#  2482,
#  3436,
#  3770,
#  4498,
#  6584,
#  2133,
#  2329,
#  2843,
#  2249,
#  3658,
#  2006,
#  4380,
#  2063,
#  2985]

# %%
plt.plot(pogo.gap_vector_)

# %%
plt.plot(pogo.gap_vector_[:pogo.candidates_[0]])

# %%
silhouette_indices, silhouette_array = pogo.plot_silhouette()
# Out:
# Maximum Silhouette: 4003

# %%
score_indices, score_array = pogo.plot_silhouette_score()
# Out:
# Maximum Silhouette Score: 3035

# %%
rand_indices, rand_array = pogo.plot_rand_score(y)
# Out:
# Maximum Rand Score: 4498

# %%
#DBSCAN Demo Data from scikitlearn
from sklearn.preprocessing import StandardScaler

centers = [[1, 1], [-1, -1], [1, -1]]
X, y = datasets.make_blobs(
    n_samples=750, centers=centers, cluster_std=0.4, random_state=0
)

X = StandardScaler().fit_transform(X)
filename = 'dbscan-demo-data'

# %%
size=8
plt.figure(figsize=(size,size))
plt.scatter(X[:, 0], X[:, 1],
            s=25, 
            c=y,
            marker="o",
            cmap='tab10',
            norm=None,
            alpha=.7,
            edgecolor="k")

# %%
pogo = Pogo()
pogo.fit(X)
pogo.plot()

# %%
pogo.initial_idx_
# Out:
# 3904

# %%
pogo.idx_
# Out:
# 3885

# %%
pogo.candidates_[:20]
# Out:
# [3904,
#  4182,
#  7424,
#  4817,
#  5875,
#  10681,
#  9669,
#  5532,
#  3004,
#  5290,
#  3227,
#  6928,
#  3402,
#  4609,
#  5136,
#  8461,
#  3319,
#  3171,
#  8104,
#  3616]

# %%
plt.plot(pogo.gap_vector_)

# %%
plt.plot(pogo.gap_vector_[:pogo.candidates_[0]])

# %%
silhouette_indices, silhouette_array = pogo.plot_silhouette()
# Out:
# Maximum Silhouette: 3885

# %%
score_indices, score_array = pogo.plot_silhouette_score()
# Out:
# Maximum Silhouette Score: 3004

# %%
rand_indices, rand_array = pogo.plot_rand_score(y)
# Out:
# Maximum Rand Score: 3885

# %%
urls_with_ground_truth = ['https://cs.joensuu.fi/sipu/datasets/D31.txt',
        'https://cs.joensuu.fi/sipu/datasets/spiral.txt',
        'https://cs.joensuu.fi/sipu/datasets/pathbased.txt',
        'https://cs.joensuu.fi/sipu/datasets/R15.txt']

urls_without_ground_truth = ['https://cs.joensuu.fi/sipu/datasets/D31.txt',
        'https://cs.joensuu.fi/sipu/datasets/spiral.txt',
        'https://cs.joensuu.fi/sipu/datasets/overlap.txt',
        'https://cs.joensuu.fi/sipu/datasets/pathbased.txt',
        'https://cs.joensuu.fi/sipu/datasets/a1.txt',
        'https://cs.joensuu.fi/sipu/datasets/R15.txt']

ground_truth_urls = ['https://cs.joensuu.fi/sipu/datasets/overlap.pa'
    
]

urls_with_ground_truth = {
    urlparse(url).path.strip('/').split('/')[-1] : url for url in urls_with_ground_truth
}


urls_without_ground_truth = {
    urlparse(url).path.strip('/').split('/')[-1] : url for url in urls_without_ground_truth
}


ground_truth = {
    urlparse(url).path.strip('/').split('/')[-1] : url for url in ground_truth_urls
}

# %%
def return_dataset(filename):
    if filename in urls_with_ground_truth:
        url= urls_with_ground_truth[filename]
        print(url)
        parse = urlparse(url)
        print(filename)
        raw_data = urlopen(url)
        data = np.loadtxt(raw_data)

        print(data.shape)
        print(data[:10])

        y = data[:,2]
        print(y.shape)
        X = data[:,:2]
        print(X.shape)
        return X, y, filename

# %%
X, y, filename = return_dataset('R15.txt')
# Out:
# https://cs.joensuu.fi/sipu/datasets/R15.txt
# R15.txt
# (600, 3)
# [[ 9.802 10.132  1.   ]
#  [10.35   9.768  1.   ]
#  [10.098  9.988  1.   ]
#  [ 9.73   9.91   1.   ]
#  [ 9.754 10.43   1.   ]
#  [ 9.836  9.902  1.   ]
#  [10.238  9.866  1.   ]
#  [ 9.53   9.862  1.   ]
#  [10.154  9.82   1.   ]
#  [ 9.336 10.456  1.   ]]
# (600,)
# (600, 2)

# %%
size=8
plt.figure(figsize=(size,size))
plt.scatter(X[:, 0], X[:, 1],
            s=25, 
            c=y,
            marker="o",
            cmap='tab10',
            norm=None,
            alpha=.7,
            edgecolor="k")

# %%
pogo = Pogo()
pogo.fit(X)
pogo.plot()

# %%
pogo.initial_idx_
# Out:
# 7643

# %%
pogo.idx_
# Out:
# 7259

# %%
pogo.candidates_[:20]
# Out:
# [7643,
#  6053,
#  3807,
#  4346,
#  7259,
#  5481,
#  6889,
#  3187,
#  5236,
#  4962,
#  5887,
#  3481,
#  2781,
#  3613,
#  4837,
#  2606,
#  2452,
#  2933,
#  3018,
#  5160]

# %%
plt.plot(pogo.gap_vector_)

# %%
plt.plot(pogo.gap_vector_[:pogo.candidates_[0]])

# %%
silhouette_indices, silhouette_array = pogo.plot_silhouette()
# Out:
# Maximum Silhouette: 7259

# %%
score_indices, score_array = pogo.plot_silhouette_score()
# Out:
# Maximum Silhouette Score: 6053

# %%
rand_indices, rand_array = pogo.plot_rand_score(y)
# Out:
# Maximum Rand Score: 2920

# %%
X, y, filename = return_dataset('D31.txt')
# Out:
# https://cs.joensuu.fi/sipu/datasets/D31.txt
# D31.txt
# (3100, 3)
# [[25.0514  5.7475  1.    ]
#  [26.6614  7.3414  1.    ]
#  [25.2653  6.2466  1.    ]
#  [25.2285  4.7447  1.    ]
#  [25.7529  5.1564  1.    ]
#  [24.0785  5.6693  1.    ]
#  [25.2722  6.8676  1.    ]
#  [24.6535  6.2443  1.    ]
#  [26.9834  6.633   1.    ]
#  [25.7437  6.3179  1.    ]]
# (3100,)
# (3100, 2)

# %%
pogo = Pogo()
pogo.fit(X)
pogo.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-4ffa20efc810> in <module>
#       1 pogo = Pogo()
# ----> 2 pogo.fit(X)
#       3 pogo.plot()
#
# ~/Desktop/ds/parameter-free-topological-clustering/pogo.py in fit(self, X, y)
#     158             if candidates[i] < candidates[0]:
#     159
# --> 160                 current_silhouette = metrics.silhouette_score(self.X,np.array(list(cluster_dict_list[idx].values())), metric="euclidean")
#     161                 current_normed_silhouette = (current_silhouette + 1)/2
#     162
#
# ~/Desktop/ds/env/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/Desktop/ds/env/lib/python3.8/site-packages/sklearn/metrics/cluster/_unsupervised.py in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     115         else:
#     116             X, labels = X[indices], labels[indices]
# --> 117     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#     118
#     119
#
# ~/Desktop/ds/env/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/Desktop/ds/env/lib/python3.8/site-packages/sklearn/metrics/cluster/_unsupervised.py in silhouette_samples(X, labels, metric, **kwds)
#     232     reduce_func = functools.partial(_silhouette_reduce,
#     233                                     labels=labels, label_freqs=label_freqs)
# --> 234     results = zip(*pairwise_distances_chunked(X, reduce_func=reduce_func,
#     235                                               **kwds))
#     236     intra_clust_dists, inter_clust_dists = results
#
# ~/Desktop/ds/env/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1614         else:
#    1615             X_chunk = X[sl]
# -> 1616         D_chunk = pairwise_distances(X_chunk, Y, metric=metric,
#    1617                                      n_jobs=n_jobs, **kwds)
#    1618         if ((X is Y or Y is None)
#
# ~/Desktop/ds/env/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/Desktop/ds/env/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1777         func = partial(distance.cdist, metric=metric, **kwds)
#    1778
# -> 1779     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1780
#    1781
#
# ~/Desktop/ds/env/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1358
#    1359     if effective_n_jobs(n_jobs) == 1:
# -> 1360         return func(X, Y, **kwds)
#    1361
#    1362     # enforce a threading backend to prevent data communication overhead
#
# ~/Desktop/ds/env/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/Desktop/ds/env/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     310         distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     311         distances += XX
# --> 312         distances += YY
#     313     np.maximum(distances, 0, out=distances)
#     314
#
# KeyboardInterrupt:

# %%
pogo.initial_idx_

# %%
pogo.idx_

# %%
pogo.candidates_[:40]

# %%
plt.plot(pogo.gap_vector_)

# %%
plt.plot(pogo.gap_vector_[:pogo.candidates_[0]])

# %%
silhouette_indices, silhouette_array = pogo.plot_silhouette()

# %%
score_indices, score_array = pogo.plot_silhouette_score()

# %%
rand_indices, rand_array = pogo.plot_rand_score(y)

# %%
fig, axes = plt.subplots(nrows=4, ncols=2,figsize=(8,12))

X, y = datasets.make_blobs(n_samples=200, centers=1, n_features=2,
                   random_state=0)
X = np.append(X,np.copy(X)+6,axis=0)
y = np.append(y, np.copy(y)+6, axis=0)
pogo.fit(X)

axes[0, 0].scatter(X[:,0],X[:,1],c=pogo.labels_)
axes[0, 1].plot(pogo.gap_vector_)

X, y = datasets.make_blobs(n_samples=200, centers=1, n_features=2,
                   random_state=0)
X = np.append(X,np.copy(X)+8,axis=0)
y = np.append(y, np.copy(y)+8, axis=0)
pogo.fit(X)

axes[1, 0].scatter(X[:,0],X[:,1],c=pogo.labels_)
axes[1, 1].plot(pogo.gap_vector_)

X, y = datasets.make_blobs(n_samples=200, centers=1, n_features=2,
                   random_state=0)
X = np.append(X,np.copy(X)+10,axis=0)
y = np.append(y, np.copy(y)+10, axis=0)
pogo.fit(X)

axes[2, 0].scatter(X[:,0],X[:,1],c=pogo.labels_)
axes[2, 1].plot(pogo.gap_vector_)

X, y = datasets.make_blobs(n_samples=200, centers=1, n_features=2,
                   random_state=0)
X = np.append(X,np.copy(X)+12,axis=0)
y = np.append(y, np.copy(y)+12, axis=0)
pogo.fit(X)

axes[3, 0].scatter(X[:,0],X[:,1],c=pogo.labels_)
axes[3, 1].plot(pogo.gap_vector_)

plt.savefig('separating-blobs-testset')

plt.show()
